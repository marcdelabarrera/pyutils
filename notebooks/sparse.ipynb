# %%
from pyutils.jax.differential import kron
from jax.experimental.sparse import BCOO
import jax.numpy as jnp

# %%
A = BCOO.fromdense(jnp.array([[1, 0, 0], [0, 2, 0], [0, 0, 3]]))
B = BCOO.fromdense(jnp.array([[0, 4], [5, 0]]))
C = kron(A, B)

# %%
C
# Out:
# BCOO(int32[6, 6], nse=6)
