# %%
import pandas as pd
from pyutils.econometrics.r import feols

# %%
df = pd.DataFrame({"x":[1,2,3,4], "y":[2,4,6,7], "group":["a","a","b","b"]})

# %%
feols("y~x|group", data=df)
# Out:
#           Estimate  Std. Error  t value  Pr(>|t|)
# variable
# x              1.5         0.5      3.0  0.204833
